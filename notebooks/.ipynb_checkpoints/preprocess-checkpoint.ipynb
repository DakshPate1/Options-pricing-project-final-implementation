# %%
using JLD2, DataFrames
keys(load("../data/spy_clean_valid_iv.jld2"))

# %%
@load "../data/spy_options_with_rates.jld2" df
# Out:
# ┌ Warning: type DataFrames.DataFrame does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type DataFrames.Index does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type InlineStrings.String31 does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:472
# ArgumentError: There is no UInt type with 32 bytes
#
# Stacktrace:
#   [1] uintofsize
#     @ ~/.julia/packages/JLD2/WDhXU/src/misc.jl:132 [inlined]
#   [2] reconstruct_bitstype
#     @ ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:465 [inlined]
#   [3] constructrr(f::JLD2.JLDFile{JLD2.MmapIO}, unk::Type{JLD2.UnknownType{Symbol("InlineStrings.String31"), Tuple{}}}, dt::JLD2.BasicDatatype, attrs::Vector{JLD2.ReadAttribute})
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:473
#   [4] jltype(f::JLD2.JLDFile{JLD2.MmapIO}, sdt::JLD2.SharedDatatype)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:122
#   [5] read_data(f::JLD2.JLDFile{JLD2.MmapIO}, dataspace::JLD2.ReadDataspace, dt::JLD2.H5Datatype, layout::JLD2.DataLayout, filters::JLD2.Filters.FilterPipeline{Tuple{}}, header_offset::JLD2.RelOffset, attributes::Vector{JLD2.ReadAttribute})
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/datasets.jl:67
#   [6] load_dataset(f::JLD2.JLDFile{JLD2.MmapIO}, offset::JLD2.RelOffset)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/datasets.jl:48
#   [7] jlconvert(::JLD2.MappedRepr{AbstractVector, JLD2.RelOffset}, f::JLD2.JLDFile{JLD2.MmapIO}, ptr::Ptr{Nothing}, ::JLD2.RelOffset)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/writing_datatypes.jl:338
#   [8] macro expansion
#     @ ~/.julia/packages/JLD2/WDhXU/src/io/dataio.jl:125 [inlined]
#   [9] macro expansion
#     @ ./simdloop.jl:77 [inlined]
#  [10] read_array!(v::Vector{AbstractVector}, f::JLD2.JLDFile{JLD2.MmapIO}, rr::JLD2.MappedRepr{AbstractVector, JLD2.RelOffset})
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/io/dataio.jl:122
#  [11] read_array(f::JLD2.JLDFile{JLD2.MmapIO}, dataspace::JLD2.ReadDataspace, rr::JLD2.ReadRepresentation, layout::JLD2.DataLayout, filters::JLD2.Filters.FilterPipeline{Tuple{}}, header_offset::JLD2.RelOffset, attributes::Vector{JLD2.ReadAttribute})
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/datasets.jl:248
#  [12] read_data(f::JLD2.JLDFile{JLD2.MmapIO}, ::JLD2.MappedRepr{Any, JLD2.RelOffset}, read_dataspace::Tuple{JLD2.ReadDataspace, JLD2.RelOffset, JLD2.DataLayout, JLD2.Filters.FilterPipeline{Tuple{}}}, attributes::Vector{JLD2.ReadAttribute})
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/datasets.jl:136
#  [13] read_data(f::JLD2.JLDFile{JLD2.MmapIO}, dataspace::JLD2.ReadDataspace, dt::JLD2.H5Datatype, layout::JLD2.DataLayout, filters::JLD2.Filters.FilterPipeline{Tuple{}}, header_offset::JLD2.RelOffset, attributes::Vector{JLD2.ReadAttribute})
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/datasets.jl:84
#  [14] load_dataset(f::JLD2.JLDFile{JLD2.MmapIO}, offset::JLD2.RelOffset)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/datasets.jl:48
#  [15] jlconvert(::JLD2.MappedRepr{Any, JLD2.RelOffset}, f::JLD2.JLDFile{JLD2.MmapIO}, ptr::Ptr{Nothing}, ::JLD2.RelOffset)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/writing_datatypes.jl:338
#  [16] jlconvert(::JLD2.MappedRepr{JLD2.ReconstructedMutable{:DataFrame, (:columns, :colindex, :metadata, :colmetadata, :allnotemetadata), Tuple{Any, JLD2.ReconstructedMutable{:Index, (:lookup, :names), Tuple{Any, Any}}, Any, Any, Bool}}, JLD2.OnDiskRepresentation{(0, 8, 24, 32, 40), Tuple{Any, JLD2.ReconstructedMutable{:Index, (:lookup, :names), Tuple{Any, Any}}, Any, Any, Bool}, Tuple{JLD2.RelOffset, JLD2.OnDiskRepresentation{(0, 8), Tuple{Any, Any}, Tuple{JLD2.RelOffset, JLD2.RelOffset}, 16}, JLD2.RelOffset, JLD2.RelOffset, Bool}, 41}}, f::JLD2.JLDFile{JLD2.MmapIO}, ptr::Ptr{Nothing}, header_offset::JLD2.RelOffset)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:653
#  [17] read_scalar(f::JLD2.JLDFile{JLD2.MmapIO}, rr::Any, header_offset::JLD2.RelOffset)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/io/dataio.jl:107
#  [18] read_data(f::JLD2.JLDFile{JLD2.MmapIO}, rr::Any, read_dataspace::Tuple{JLD2.ReadDataspace, JLD2.RelOffset, JLD2.DataLayout, JLD2.Filters.FilterPipeline{Tuple{}}}, attributes::Vector{JLD2.ReadAttribute})
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/datasets.jl:96
#  [19] read_data(f::JLD2.JLDFile{JLD2.MmapIO}, dataspace::JLD2.ReadDataspace, dt::JLD2.H5Datatype, layout::JLD2.DataLayout, filters::JLD2.Filters.FilterPipeline{Tuple{}}, header_offset::JLD2.RelOffset, attributes::Vector{JLD2.ReadAttribute})
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/datasets.jl:84
#  [20] load_dataset(f::JLD2.JLDFile{JLD2.MmapIO}, offset::JLD2.RelOffset)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/datasets.jl:48
#  [21] getindex(g::JLD2.Group{JLD2.JLDFile{JLD2.MmapIO}}, name::String)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/groups.jl:99
#  [22] read
#     @ ~/.julia/packages/JLD2/WDhXU/src/JLD2.jl:368 [inlined]
#  [23] (::var"#2#3")(f::JLD2.JLDFile{JLD2.MmapIO})
#     @ Main ~/.julia/packages/JLD2/WDhXU/src/loadsave.jl:153
#  [24] jldopen(f::Function, args::String; kws::@Kwargs{})
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/loadsave.jl:4
#  [25] jldopen(f::Function, args::String)
#     @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/loadsave.jl:1
#  [26] top-level scope
#     @ In[2]:1
#  [27] macro expansion
#     @ ~/.julia/packages/JLD2/WDhXU/src/loadsave.jl:152 [inlined]

# %%
first(df,5)
# Out:
# UndefVarError: `df` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[3]:1

# %%
for col in names(df)
    println(col)
end
# Out:
# Column1
# level_0
# QUOTE_UNIXTIME
# QUOTE_READTIME
# QUOTE_DATE
# QUOTE_TIME_HOURS
# UNDERLYING_LAST
# EXPIRE_DATE
# EXPIRE_UNIX
# DTE
# C_DELTA
# C_GAMMA
# C_VEGA
# C_THETA
# C_RHO
# C_IV
# C_VOLUME
# C_LAST
# C_SIZE
# C_BID
# C_ASK
# STRIKE
# P_BID
# P_ASK
# P_SIZE
# P_LAST
# P_DELTA
# P_GAMMA
# P_VEGA
# P_THETA
# P_RHO
# P_IV
# P_VOLUME
# STRIKE_DISTANCE
# STRIKE_DISTANCE_PCT
# r

# %%
first(df[:,[:UNDERLYING_LAST,:STRIKE,:DTE,:r,:C_IV,:P_IV]],5)
# Out:
# 5×6 DataFrame
#  Row │ UNDERLYING_LAST  STRIKE   DTE      r         C_IV      P_IV
#      │ Float64          Float64  Float64  Float64?  Float64   Float64
# ─────┼────────────────────────────────────────────────────────────────
#    1 │          366.62    357.0      0.0      3.46   0.22754  0.24586
#    2 │          366.62    359.0      0.0      3.46   0.18367  0.19937
#    3 │          366.62    360.0      0.0      3.46   0.17477  0.17624
#    4 │          366.62    366.0      0.0      3.46  -0.00011  0.05915
#    5 │          366.62    367.0      0.0      3.46   0.03799  0.07187

# %%
using JLD2, DataFrames, Statistics  # ← Add Statistics here

println("🔍 CHECKING FOR INVALID IV VALUES\n")

# 1. Find negative IVs
negative_call_iv = filter(row -> row.C_IV < 0, df)
negative_put_iv = filter(row -> row.P_IV < 0, df)

println("Negative Call IVs: $(nrow(negative_call_iv))")
println("Negative Put IVs: $(nrow(negative_put_iv))")

if nrow(negative_call_iv) > 0
    println("\n📋 Sample negative Call IV rows:")
    println(first(select(negative_call_iv, :QUOTE_DATE, :STRIKE, :C_IV, :C_BID, :C_ASK, :C_VOLUME), 5))
end

# 2. Check for zeros
zero_call_iv = filter(row -> row.C_IV == 0, df)
println("\nZero Call IVs: $(nrow(zero_call_iv))")

# 3. Check for extremely low values
very_low_iv = filter(row -> 0 < row.C_IV < 0.01, df)  # < 1%
println("Very low Call IVs (<1%): $(nrow(very_low_iv))")

# 4. Check distribution
println("\n📊 IV Distribution:")
println("  Min:    $(minimum(df.C_IV))")
println("  1st %:  $(quantile(df.C_IV, 0.01))")
println("  5th %:  $(quantile(df.C_IV, 0.05))")
println("  Median: $(median(df.C_IV))")
println("  Mean:   $(round(mean(df.C_IV), digits=3))")
println("  95th %: $(quantile(df.C_IV, 0.95))")
println("  Max:    $(maximum(df.C_IV))")

# 5. Look at characteristics of bad IV rows
if nrow(negative_call_iv) > 0
    println("\n🔍 Characteristics of negative IV rows:")
    println("  Avg volume: $(round(mean(negative_call_iv.C_VOLUME), digits=1))")
    println("  Avg bid: \$$(round(mean(negative_call_iv.C_BID), digits=2))")
    println("  Avg strike distance: $(round(mean(abs.(negative_call_iv.STRIKE_DISTANCE_PCT)), digits=1))%")
end
# Out:
# 🔍 CHECKING FOR INVALID IV VALUES
#
# Negative Call IVs: 17806
# Negative Put IVs: 39301
#
# 📋 Sample negative Call IV rows:
# 5×6 DataFrame
#  Row │ QUOTE_DATE  STRIKE   C_IV      C_BID    C_ASK    C_VOLUME
#      │ Dates.Date  Float64  Float64   Float64  Float64  Float64
# ─────┼───────────────────────────────────────────────────────────
#    1 │ 2022-10-03    366.0  -0.00011     0.58     0.69   80984.0
#    2 │ 2022-10-03    345.0  -0.00032    21.45    21.81      22.0
#    3 │ 2022-10-03    346.0  -0.00032    20.46    20.82      15.0
#    4 │ 2022-10-03    280.0  -0.0004     86.44    86.83       0.0
#    5 │ 2022-10-03    315.0  -8.0e-5     51.49    51.9        0.0
#
# Zero Call IVs: 396
# Very low Call IVs (<1%): 22523
#
# 📊 IV Distribution:
#   Min:    -0.0005
#   1st %:  0.05561179999999993
#   5th %:  0.10975
#   Median: 0.22411
#   Mean:   0.305
#   95th %: 0.70465
#   Max:    54.06381
#
# 🔍 Characteristics of negative IV rows:
#   Avg volume: 202.3
#   Avg bid: $100.06
#   Avg strike distance: 0.3%

# %%
using JLD2, DataFrames, Statistics



println("🧹 CLEANING IV OUTLIERS\n")

initial = nrow(df)
println("Starting: $initial rows")

# Define reasonable IV bounds for SPY
IV_MIN = 0.05   # 5% minimum (calm market)
IV_MAX = 1.50   # 150% maximum (even COVID didn't hit this for SPY)

# Filter
df_clean = filter(row ->
    IV_MIN <= row.C_IV <= IV_MAX &&
    IV_MIN <= row.P_IV <= IV_MAX,
    df
)

removed = initial - nrow(df_clean)
pct_removed = round(100 * removed / initial, digits=2)

println("Removed: $removed rows ($pct_removed%)")
println("Remaining: $(nrow(df_clean)) rows")

# Check new distribution
println("\n📊 Cleaned IV Distribution:")
println("  Min:    $(round(minimum(df_clean.C_IV), digits=4))")
println("  5th %:  $(round(quantile(df_clean.C_IV, 0.05), digits=4))")
println("  Median: $(round(median(df_clean.C_IV), digits=4))")
println("  Mean:   $(round(mean(df_clean.C_IV), digits=4))")
println("  95th %: $(round(quantile(df_clean.C_IV, 0.95), digits=4))")
println("  Max:    $(round(maximum(df_clean.C_IV), digits=4))")

# Save
@save "../data/spy_clean_valid_iv.jld2" df_clean
println("\n✅ Saved: data/spy_clean_valid_iv.jld2")
# Out:
# 🧹 CLEANING IV OUTLIERS
#
# Starting: 4195810 rows
# Removed: 269555 rows (6.42%)
# Remaining: 3926255 rows
#
# 📊 Cleaned IV Distribution:
#   Min:    0.05
#   5th %:  0.1163
#   Median: 0.2265
#   Mean:   0.2766
#   95th %: 0.6296
#   Max:    1.5
#
# ✅ Saved: data/processed/spy_clean_valid_iv.jld2
