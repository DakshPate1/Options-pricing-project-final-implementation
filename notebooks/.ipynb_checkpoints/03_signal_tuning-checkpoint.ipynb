# %%
include("../src/signals/decision_rules.jl")
include("../src/signals/signal_generator.jl")

using .DecisionRules
using .SignalGenerator

fs = FuzzySignal(90, 100, 110)

println(evaluate_rules(fs))
println(crisp_signal(fs))
# Out:
# Dict(:StrongSell => 0.010000000000000002, :StrongBuy => 0.010000000000000002, :Buy => 0.1, :Hold => 0.8, :Sell => 0.1)
# Hold
